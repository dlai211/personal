# %% [markdown]
# <a href="https://colab.research.google.com/github/dlai211/Personal/blob/main/RO_genesis/Guild.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Note: If you are viewing the coding in github, plots from plotly module are not showing. Please see in the colab link.

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import plotly.express as px
import pandas as pd

# %% [markdown]
# ## Changes: spent 1,556,000 guild fund in level 2 Emperium

# %% [markdown]
# ## Current Data I Collected

# %%
guild_fund = [6.091e7, 6.248e7, 6.388e7, 6.595e7, 6.771e7, 6.932e7, 7.127e7, 7.357e7, 7.586e7]
guild_fund_cont = [6.202e7, 6.372e7, 6.530e7, 6.694e7, 6.852e7, 7.062e7, 7.267e7, 7.4e7, 7.545e7, 7.684e7, 7.897e7, 8.05e7, 8.24e7, 8.376e7, 8.538e7, 8.644e7, 8.762e7, 8.917e7, 9.048e7, 9.175e7, 9.296e7]

guild_fund_fit = [i-1.556e7 for i in guild_fund]
guild_fund_fit = guild_fund_fit + guild_fund_cont
guild_fund = guild_fund + guild_fund_cont

diff = np.diff(guild_fund).tolist()
diff_fit = np.diff(guild_fund_fit).tolist()
diff.insert(0,1.2e6)
diff_fit.insert(0,1.2e6)
num_day = len(guild_fund)

data = {'Date': pd.date_range("3/19/2022", periods=num_day), 'Guild Fund': guild_fund, 'Daily Gain': diff}
data_fit = {'Date': pd.date_range("3/19/2022", periods=num_day), 'Guild Fund': guild_fund_fit, 'Daily Gain': diff_fit}
df = pd.DataFrame(data, index=None)
df_fit = pd.DataFrame(data_fit, index=None)
df_fit
# Out:
#          Date  Guild Fund  Daily Gain
# 0  2022-03-19  45350000.0   1200000.0
# 1  2022-03-20  46920000.0   1570000.0
# 2  2022-03-21  48320000.0   1400000.0
# 3  2022-03-22  50390000.0   2070000.0
# 4  2022-03-23  52150000.0   1760000.0
# 5  2022-03-24  53760000.0   1610000.0
# 6  2022-03-25  55710000.0   1950000.0
# 7  2022-03-26  58010000.0   2300000.0
# 8  2022-03-27  60300000.0   2290000.0
# 9  2022-03-28  62020000.0   1720000.0
# 10 2022-03-29  63720000.0   1700000.0
# 11 2022-03-30  65300000.0   1580000.0
# 12 2022-03-31  66940000.0   1640000.0
# 13 2022-04-01  68520000.0   1580000.0
# 14 2022-04-02  70620000.0   2100000.0
# 15 2022-04-03  72670000.0   2050000.0
# 16 2022-04-04  74000000.0   1330000.0
# 17 2022-04-05  75450000.0   1450000.0
# 18 2022-04-06  76840000.0   1390000.0
# 19 2022-04-07  78970000.0   2130000.0
# 20 2022-04-08  80500000.0   1530000.0
# 21 2022-04-09  82400000.0   1900000.0
# 22 2022-04-10  83760000.0   1360000.0
# 23 2022-04-11  85380000.0   1620000.0
# ...

# %% [markdown]
# ## Visualizing Sample Guild Fund and Daily Gain

# %%
pd.options.plotting.backend = "plotly"
#fig = px.line(df, x="year", y="lifeExp", color='country')
px.line(df, x='Date', y='Guild Fund', text='Daily Gain', markers=True, title='Genesis Guild Fund Record')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Plotting the Best Fit Line (linear regression)

# %%
px.scatter(df_fit, x="Date", y="Guild Fund", text='Daily Gain', trendline="ols", trendline_scope="overall", title='Guild Fund Fitted Line')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## A Table of Predicted Guild Fund and Predicted Daily Gain (using data the latest week).

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression()
reg.fit(df_fit['Date'][-7:-1].values.reshape(-1,1), df_fit['Guild Fund'][-7:-1])

print(f'Model slope: {reg.coef_[0]}, Model intercept: {reg.intercept_}')
date_pred = pd.date_range("04/01/2022", periods=30)
y_pred = reg.predict(date_pred.values.astype(float).reshape(-1,1))
diff_pred = np.diff(y_pred).tolist()
diff_pred = np.ones(len(y_pred))*diff_pred[0]

pred = pd.DataFrame({'Predicted Date': date_pred, 'Predicted Guild Fund': y_pred, 'Predicted Daily Gain': diff_pred})
pred
# Out:
# Model slope: 1.5052910052910056e-08, Model intercept: -24746588380.952385
#    Predicted Date  Predicted Guild Fund  Predicted Daily Gain
# 0      2022-04-01          7.221619e+07          1.300571e+06
# 1      2022-04-02          7.351676e+07          1.300571e+06
# 2      2022-04-03          7.481733e+07          1.300571e+06
# 3      2022-04-04          7.611790e+07          1.300571e+06
# 4      2022-04-05          7.741848e+07          1.300571e+06
# 5      2022-04-06          7.871905e+07          1.300571e+06
# 6      2022-04-07          8.001962e+07          1.300571e+06
# 7      2022-04-08          8.132019e+07          1.300571e+06
# 8      2022-04-09          8.262076e+07          1.300571e+06
# 9      2022-04-10          8.392133e+07          1.300571e+06
# 10     2022-04-11          8.522190e+07          1.300571e+06
# 11     2022-04-12          8.652248e+07          1.300571e+06
# 12     2022-04-13          8.782305e+07          1.300571e+06
# ...

# %% [markdown]
# ## The Date we will Reached the Goal (Reach lvl 3 Guild)

# %%
goal = 9.459e7
pred.iloc[pred[pred['Predicted Guild Fund'].gt(goal)].index[0]]
# Out:
# Predicted Date          2022-04-19 00:00:00
# Predicted Guild Fund        95626476.190475
# Predicted Daily Gain          1300571.42857
# Name: 18, dtype: object
